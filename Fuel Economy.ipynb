# %%
import pandas as pd
import pandas_profiling

# %%
df = pd.read_csv('vehicles.csv', low_memory=False, index_col='id')

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>83 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>38150 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>13.6% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>23.9 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>657.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>24 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>23 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>36 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>UCity</code> is highly correlated with <code>highway08</code> (ρ = 0.92273) <span class="label label-primary">Rejected</span></l><li><code>UCityA</code> is highly correlated with <code>highwayA08U</code> (ρ = 0.91745) <span class="label label-primary">Rejected</span></l><li><code>UHighway</code> is highly correlated with <code>UCity</code> (ρ = 0.92222) <span class="label label-primary">Rejected</span></l><li><code>UHighwayA</code> is highly correlated with <code>UCityA</code> (ρ = 0.96498) <span class="label label-primary">Rejected</span></l><li><code>atvType</code> has 35096 / 92.0% missing values <span class="label label-default">Missing</span></l><li><code>barrelsA08</code> has 36712 / 96.2% zeros</l><li><code>c240Dscr</code> has 38098 / 99.9% missing values <span class="label label-default">Missing</span></l><li><code>c240bDscr</code> has 38100 / 99.9% missing values <span class="label label-default">Missing</span></l><li><code>charge120</code> has constant value 0 <span class="label label-primary">Rejected</span></l><li><code>charge240</code> is highly skewed (γ1 = 20.19)</l><li><code>charge240</code> has 37971 / 99.5% zeros</l><li><code>charge240b</code> is highly skewed (γ1 = 28.547)</l><li><code>charge240b</code> has 38101 / 99.9% zeros</l><li><code>city08U</code> has 29662 / 77.8% zeros</l><li><code>cityA08</code> has 36712 / 96.2% zeros</l><li><code>cityA08U</code> is highly correlated with <code>cityA08</code> (ρ = 0.93792) <span class="label label-primary">Rejected</span></l><li><co

# %%
make_model = df.groupby(['make', 'model', 'year']).agg('mean')
make_model.head(10)
# Out:
#                                            barrels08  barrelsA08  charge120  \
# make             model               year
# AM General       DJ Po Vehicle 2WD   1984  19.388824         0.0        0.0
#                  FJ8c Post Office    1984  25.354615         0.0        0.0
#                  Post Office DJ5 2WD 1985  20.600625         0.0        0.0
#                  Post Office DJ8 2WD 1985  25.354615         0.0        0.0
# ASC Incorporated GNX                 1987  20.600625         0.0        0.0
# Acura            2.2CL/3.0CL         1997  15.065508         0.0        0.0
#                  2.3CL/3.0CL         1998  15.065508         0.0        0.0
#                                      1999  15.065508         0.0        0.0
#                  2.5TL               1995  16.480500         0.0        0.0
#                  2.5TL/3.2TL         1996  16.914197         0.0        0.0
#
#                                            charge240     city08  city08U  \
# make             model               year
# AM General       DJ Po Vehicle 2WD   1984        0.0  18.000000      0.0
#                  FJ8c Post Office    1984        0.0  13.000000      0.0
#                  Post Office DJ5 2WD 1985        0.0  16.000000      0.0
#                  Post Office DJ8 2WD 1985        0.0  13.000000      0.0
# ASC Incorporated GNX                 1987        0.0  14.000000      0.0
# Acura            2.2CL/3.0CL         1997        0.0  20.000000      0.0
#                  2.3CL/3.0CL         1998        0.0  19.000000      0.0
#                                      1999        0.0  19.333333      0.0
#                  2.5TL               1995        0.0  18.000000      0.0
#                  2.5TL/3.2TL         1996        0.0  17.500000      0.0
#
#                                            cityA08  cityA08U  cityCD  cityE  \
# make             model               year
# AM General       DJ Po Vehicle 2WD   1984      0.0       0.0     0.0    0.0
#                  FJ8c Post Office    1984      0.0       0.0     0.0    0.0
#                  Post Office DJ5 2WD 1985      0.0       0.0     0.0    0.0
#                  Post Office DJ8 2WD 1985      0.0       0.0     0.0    0.0
# ASC Incorporated GNX                 1987      0.0       0.0     0.0    0.0
# Acura            2.2CL/3.0CL         1997      0.0       0.0     0.0    0.0
#                  2.3CL/3.0CL         1998      0.0       0.0     0.0    0.0
#                                      1999      0.0       0.0     0.0    0.0
#                  2.5TL               1995      0.0       0.0     0.0    0.0
#                  2.5TL/3.2TL         1996      0.0       0.0     0.0    0.0
#
#                                              ...     rangeHwyA    UCity  \
# make             model               year    ...
# AM General       DJ Po Vehicle 2WD   1984    ...           0.0  22.0000
#                  FJ8c Post Office    1984    ...           0.0  16.0000
#                  Post Office DJ5 2WD 1985    ...           0.0  20.0000
#                  Post Office DJ8 2WD 1985    ...           0.0  16.0000
# ASC Incorporated GNX                 1987    ...           0.0  17.0000
# Acura            2.2CL/3.0CL         1997    ...           0.0  25.0000
#                  2.3CL/3.0CL         1998    ...           0.0  24.4443
#                                      1999    ...           0.0  24.4818
#                  2.5TL               1995    ...           0.0  22.0000
#                  2.5TL/3.2TL         1996    ...           0.0  21.5000
#
#                                            UCityA   UHighway  UHighwayA  \
# make             model               year
# AM General       DJ Po Vehicle 2WD   1984     0.0  24.000000        0.0
#                  FJ8c Post Office    1984     0.0  18.000000        0.0
#                  Post Office DJ5 2WD 1985     0.0  23.076900        0.0
#                  Post Office DJ8 2WD 1985     0.0  18.000000        0.0
# ASC Incorporated GNX                 1987     0.0  29.000000        0.0
# Acura            2.2CL/3.0CL         1997     0.0  37.547000        0.0
#                  2.3CL/3.0CL         1998     0.0  37.988600        0.0
#                                      1999     0.0  38.063567        0.0
#                  2.5TL               1995     0.0  32.000000        0.0
#                  2.5TL/3.2TL         1996     0.0  31.384600        0.0
#
#                                            youSaveSpend  charge240b  phevCity  \
# make             model               year
# AM General       DJ Po Vehicle 2WD   1984  -3500.000000         0.0       0.0
#                  FJ8c Post Office    1984  -6500.000000         0.0       0.0
#                  Post Office DJ5 2WD 1985  -4000.000000         0.0       0.0
#                  Post Office DJ8 2WD 1985  -6500.000000         0.0       0.0
# ASC Incorporated GNX                 1987  -6250.000000         0.0       0.0
# Acura            2.2CL/3.0CL         1997  -1083.333333         0.0       0.0
#                  2.3CL/3.0CL         1998  -1083.333333         0.0       0.0
#                                      1999  -1083.333333         0.0       0.0
#                  2.5TL               1995  -3750.000000         0.0       0.0
#                  2.5TL/3.2TL         1996  -4000.000000         0.0       0.0
#
#                                            phevHwy  phevComb
# make             model               year
# AM General       DJ Po Vehicle 2WD   1984      0.0       0.0
#                  FJ8c Post Office    1984      0.0       0.0
#                  Post Office DJ5 2WD 1985      0.0       0.0
#                  Post Office DJ8 2WD 1985      0.0       0.0
# ASC Incorporated GNX                 1987      0.0       0.0
# Acura            2.2CL/3.0CL         1997      0.0       0.0
#                  2.3CL/3.0CL         1998      0.0       0.0
#                                      1999      0.0       0.0
#                  2.5TL               1995      0.0       0.0
#                  2.5TL/3.2TL         1996      0.0       0.0
#
# [10 rows x 58 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(10,6))
make_model[make_model['UCity'] > 0].sort_values(by='UCity', ascending=True)[:25]['UCity'].plot(kind='bar')
