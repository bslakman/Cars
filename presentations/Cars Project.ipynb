# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('ticks')
import numpy as np

# %% [markdown]
# ## Craigslist Data
# This data has been scraped from boston.craigslist.org using the BeautifulSoup, requests and re modules; see Craiglist.ipynb notebook for code and more details.

# %%
# %store -r all_car_info
print len(all_car_info)
all_car_info[10:15]
# Out:
# 3432
#                                                                 description  \
# link
# /gbs/cto/6038299048.html                    Family Car Cadillac CTS 2008 V6
# /sob/cto/6028224022.html                                 2011 Nissan Maxima
# /gbs/cto/6020990658.html           2005 VW Jetta 80k miles, great condition
# /gbs/cto/6038298193.html  1999 Ford Ranger XLT auto 2 wheel drive 4 cyli...
# /gbs/cto/6037009052.html                     TOYOTA 2007 !!! ONE OWNER ONLY
#
#                             location    price  mileage region    year  \
# link
# /gbs/cto/6038299048.html      Boston   3213.0      NaN   gbs/  2008.0
# /sob/cto/6028224022.html     Taunton  10500.0      NaN   sob/  2011.0
# /gbs/cto/6020990658.html               3500.0  80000.0   gbs/  2005.0
# /gbs/cto/6038298193.html       Derry   2500.0      NaN   gbs/  1999.0
# /gbs/cto/6037009052.html  PROVIDENCE   4950.0      NaN   gbs/  2007.0
#
#                          std_location
# link
# /gbs/cto/6038299048.html        bosto
# /sob/cto/6028224022.html        taunt
# /gbs/cto/6020990658.html
# /gbs/cto/6038298193.html        derry
# /gbs/cto/6037009052.html        provi

# %%
all_car_info.plot.scatter('year', 'price')
plt.ylim(0,2E5)
plt.ylabel('Price', fontdict={'fontsize': 14})
plt.xlim(1950,2020)
plt.xlabel('Year', fontdict={'fontsize': 14})
plt.title('Car prices vs. Year', fontdict={'fontsize': 16})

# %%
# %store -r regions
print len(regions)
regions.head(3)
# Out:
# 11
#                     price              mileage               year
#                      mean count           mean count         mean count
# std_location
# stone         3978.846154    26   99800.000000     5  2000.000000    23
# malde         4570.283019    53  114866.666667    15  2002.803571    56
# lowel         7052.632653    49  111285.714286     7  2000.585366    41

# %%
ax = regions['price','mean'].plot.bar(position=0, width=0.3, alpha=0.8, legend=True)
ax.set_title('Average Price and Mileage of Used Cars in Greater Boston, by region', fontdict={'fontsize':16})
ax.set_xlabel('City/Town', fontdict={'fontsize':14})
ax.set_xticklabels(regions.index, fontdict={'fontsize':12})
ax.set_ylabel('Price($)', fontdict={'fontsize':14})
ax.set_yticklabels(range(0,20000,2500), fontdict={'fontsize':12})
ax = regions['mileage','mean'].plot.bar(secondary_y=True, color='red', position=1, width=0.3, alpha=0.5, legend=True)
ax.set_ylabel('Mileage', fontdict={'fontsize':14})
ax.set_yticklabels(range(0,160000,20000), fontdict={'fontsize':12})
sns.despine(top=True, right=False)
fig=ax.get_figure()
fig.set_size_inches(10,4)

# %% [markdown]
# ## Modeling
# A linear regression model was trained on year and mileage using scikit-learn.

# %%
# %store -r X_test
# %store -r y_test
# %store -r model
# %store -r scores

# %%
fig = plt.figure(figsize=(9,6))
plt.scatter(y_test, model.predict(X_test), label="predicted")
plt.plot(y_test, y_test, color='black', label="parity")
plt.title("Linear regression model prediction vs actual.\nprice = f(year, mileage), r = {0} +/- {1}".format(
    round(np.mean(scores),3), round(np.std(scores),3)), fontdict={'fontsize': 16})
plt.xlabel("Price (actual)", fontdict={'fontsize': 14})
plt.ylabel("Price (predicted)", fontdict={'fontsize': 14})
plt.legend(loc='best', fontsize='large')
plt.tight_layout()
fig.savefig('linreg.png')

# %% [markdown]
# The model isn't great, due to anomalies for more expensive cars. This is motivation for a better model using less obvious features.

# %% [markdown]
# ## Putting it together with Edmunds data
# See the Craigslist.ipynb and Edmunds.ipynb notebooks for more details. I looked at data just for Ford Focuses, due to Edmunds API limitations! Data was compared to Craigslist averages for Ford Focuses, by year.

# %%
# %matplotlib inline
# %store -r focus_years
ax = focus_years.plot(y=[('price', 'mean'), 'used_private_party', 'used_tradein', 'used_tmv_retail', 'certified'], lw=3)
ax.set_ylabel("Price ($)", fontdict={'fontsize': 14})
ax.set_yticklabels(range(-2000,18000, 2000), fontdict={'fontsize': 12})
ax.set_xlabel("Year", fontdict={'fontsize': 14})
ax.set_xticklabels(range(2000,2018,2), fontdict={'fontsize': 12})
ax.set_title("Ford Focus pricing, including Craigslist averages and Edmunds data, by year", fontdict={'fontsize': 16})
ax.legend(fontsize = 'large')
fig=ax.get_figure()
fig.set_size_inches(9,6)
#fig.savefig('ford_focus_pricing.png')

# %%
# %store -r focus_data
print len(focus_data)
focus_data[focus_data['year']==2016]
# Out:
# 177
#                                                                                    description  \
# link
# /gbs/cto/5999533717.html                              2016 Ford Focus hatchback lease takeover
# //worcester.craigslist.org/cto/5983547331.html  Ford Focus ZX3 - 5 Speed -= 30+ mpg    $$ 1650
#
#                                                  location   price  mileage  \
# link
# /gbs/cto/5999533717.html                        Wakefield   290.0      NaN
# //worcester.craigslist.org/cto/5983547331.html             1650.0      NaN
#
#                                                region    year std_location
# link
# /gbs/cto/5999533717.html                         gbs/  2016.0        wakef
# //worcester.craigslist.org/cto/5983547331.html   /wor  2016.0

# %%
focus_data[focus_data['year']==2014]
# Out:
#                                                                                     description  \
# link
# /nos/cto/5998874532.html                                2014 Ford Focus Sedan SE sports package
# /bmw/cto/6000996919.html                                               2014 Ford Focus SE Sedan
# /nwb/cto/5951866403.html                         2014 Ford Focus SE Silver - 1 Owner - Like New
# /bmw/cto/5986928247.html                                                     2014 Ford Focus ST
# /gbs/cto/5975159514.html                                                     2014 Ford Focus se
# /bmw/cto/5981878527.html                                                 2014 Ford Focus ST ST3
# //southcoast.craigslist.org/cto/5969313945.html                              2014 Ford Focus ST
#
#                                                   location    price  mileage  \
# link
# /nos/cto/5998874532.html                         Billerica  13000.0      NaN
# /bmw/cto/6000996919.html                         Arlington  11995.0      NaN
# /nwb/cto/5951866403.html                         Tewksbury  14000.0      NaN
# /bmw/cto/5986928247.html                         Lunenburg  20000.0      NaN
# /gbs/cto/5975159514.html                                        NaN      NaN
# /bmw/cto/5981878527.html                                    18000.0      NaN
# //southcoast.craigslist.org/cto/5969313945.html             16999.0      NaN
#
#                                                 region    year std_location
# link
# /nos/cto/5998874532.html                          nos/  2014.0        bille
# /bmw/cto/6000996919.html                          bmw/  2014.0        arlin
# /nwb/cto/5951866403.html                          nwb/  2014.0        tewks
# /bmw/cto/5986928247.html                          bmw/  2014.0        lunen
# /gbs/cto/5975159514.html                          gbs/  2014.0
# /bmw/cto/5981878527.html                          bmw/  2014.0
# //southcoast.craigslist.org/cto/5969313945.html   /sou  2014.0
